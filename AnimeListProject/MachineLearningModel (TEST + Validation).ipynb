# %%
import numpy as np
import sklearn 
import matplotlib.pyplot as plt
import pandas as pd
# %matplotlib inline

# %%
animeData = pd.read_csv('./animes.csv')
print(animeData)
# Out:
#          uid                                        title  \
# 0      28891                      Haikyuu!! Second Season
# 1      23273                      Shigatsu wa Kimi no Uso
# 2      34599                                Made in Abyss
# 3       5114             Fullmetal Alchemist: Brotherhood
# 4      31758             Kizumonogatari III: Reiketsu-hen
# ...      ...                                          ...
# 19306  32979                                Flip Flappers
# 19307    123                                Fushigi Yuugi
# 19308   1281                             Gakkou no Kaidan
# 19309    450  InuYasha Movie 2: Kagami no Naka no Mugenjo
# 19310     87     Mobile Suit Gundam: Char's Counterattack
#
#                                                 synopsis  \
# 0      Following their participation at the Inter-Hig...
# 1      Music accompanies the path of the human metron...
# 2      The Abyss—a gaping chasm stretching down into ...
# 3      "In order for something to be obtained, someth...
# 4      After helping revive the legendary vampire Kis...
# ...                                                  ...
# 19306  Cocona is an average middle schooler living wi...
# 19307  While visiting the National Library, junior-hi...
# 19308  Years ago, all of the ghosts in a haunted scho...
# 19309  Inuyasha and company have finally destroyed Na...
# 19310  The year is Universal Century 0093. Char Aznab...
#
#                                                    genre  \
# 0      ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1      ['Drama', 'Music', 'Romance', 'School', 'Shoun...
# 2      ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'F...
# 3      ['Action', 'Military', 'Adventure', 'Comedy', ...
# 4       ['Action', 'Mystery', 'Supernatural', 'Vampire']
# ...                                                  ...
# 19306         ['Sci-Fi', 'Adventure', 'Comedy', 'Magic']
# 19307  ['Adventure', 'Fantasy', 'Magic', 'Martial Art...
# 19308              ['Mystery', 'Horror', 'Supernatural']
# 19309  ['Action', 'Adventure', 'Comedy', 'Historical'...
# 19310  ['Military', 'Sci-Fi', 'Space', 'Drama', 'Mecha']
#
#                               aired  episodes  members  popularity  ranked  \
# 0       Oct 4, 2015 to Mar 27, 2016      25.0   489888         141    25.0
# 1      Oct 10, 2014 to Mar 20, 2015      22.0   995473          28    24.0
# 2       Jul 7, 2017 to Sep 29, 2017      13.0   581663          98    23.0
# 3        Apr 5, 2009 to Jul 4, 2010      64.0  1615084           4     1.0
# 4                       Jan 6, 2017       1.0   214621         502    22.0
# ...                             ...       ...      ...         ...     ...
# 19306   Oct 6, 2016 to Dec 29, 2016      13.0   134252         843  1070.0
# 19307   Apr 6, 1995 to Mar 28, 1996      52.0    84407        1292  1071.0
# 19308  Oct 22, 2000 to Mar 25, 2001      19.0    83093        1314  1073.0
# 19309                  Dec 21, 2002       1.0    71989        1469  1077.0
# 19310                  Mar 12, 1988       1.0    29248        2604  1081.0
#
#        score                                            img_url  \
# 0       8.82  https://cdn.myanimelist.net/images/anime/9/766...
# 1       8.83  https://cdn.myanimelist.net/images/anime/3/671...
# 2       8.83  https://cdn.myanimelist.net/images/anime/6/867...
# 3       9.23  https://cdn.myanimelist.net/images/anime/1223/...
# 4       8.83  https://cdn.myanimelist.net/images/anime/3/815...
# ...      ...                                                ...
# 19306   7.73  https://cdn.myanimelist.net/images/anime/4/822...
# 19307   7.73  https://cdn.myanimelist.net/images/anime/2/201...
# 19308   7.73  https://cdn.myanimelist.net/images/anime/9/183...
# 19309   7.73  https://cdn.myanimelist.net/images/anime/1162/...
# 19310   7.73  https://cdn.myanimelist.net/images/anime/1523/...
#
#                                                     link
# 0      https://myanimelist.net/anime/28891/Haikyuu_Se...
# 1      https://myanimelist.net/anime/23273/Shigatsu_w...
# 2      https://myanimelist.net/anime/34599/Made_in_Abyss
# 3      https://myanimelist.net/anime/5114/Fullmetal_A...
# 4      https://myanimelist.net/anime/31758/Kizumonoga...
# ...                                                  ...
# 19306  https://myanimelist.net/anime/32979/Flip_Flappers
# 19307    https://myanimelist.net/anime/123/Fushigi_Yuugi
# 19308  https://myanimelist.net/anime/1281/Gakkou_no_K...
# 19309  https://myanimelist.net/anime/450/InuYasha_Mov...
# 19310  https://myanimelist.net/anime/87/Mobile_Suit_G...
#
# [19311 rows x 12 columns]

# %%
import re

uniqueGenres = []
cleanedGenres = []
for genre in animeData['genre']:
    currentGenre = genre.split(',')
    currentGenreCleaned = re.sub(r'[\[\]\(\)\"\,]', '', genre)  # Remove non-alphanumeric characters
    # print(currentGenreCleaned)
    cleanedGenres.append(currentGenreCleaned)
    finalGenreSplit = currentGenreCleaned.split("' '")  # Split into individual genres
    for individualGenre in finalGenreSplit:
        individualGenre = re.sub(r'[\']', '', individualGenre)
        if individualGenre not in uniqueGenres and individualGenre != '':
            uniqueGenres.append(individualGenre)

print (uniqueGenres)
# Out:
# ['Comedy', 'Sports', 'Drama', 'School', 'Shounen', 'Music', 'Romance', 'Sci-Fi', 'Adventure', 'Mystery', 'Fantasy', 'Action', 'Military', 'Magic', 'Supernatural', 'Vampire', 'Slice of Life', 'Demons', 'Historical', 'Super Power', 'Mecha', 'Parody', 'Samurai', 'Seinen', 'Police', 'Psychological', 'Josei', 'Space', 'Kids', 'Shoujo Ai', 'Ecchi', 'Shoujo', 'Horror', 'Shounen Ai', 'Cars', 'Martial Arts', 'Game', 'Thriller', 'Dementia', 'Harem', 'Hentai', 'Yaoi', 'Yuri']

# %%
cleanedGenres
animeData['text'] = animeData['title'] + " " + animeData['synopsis']
print(cleanedGenres[:3])
print(animeData['text'][:3])
# Out:
# ["'Comedy' 'Sports' 'Drama' 'School' 'Shounen'", "'Drama' 'Music' 'Romance' 'School' 'Shounen'", "'Sci-Fi' 'Adventure' 'Mystery' 'Drama' 'Fantasy'"]
# 0    Haikyuu!! Second Season Following their partic...
# 1    Shigatsu wa Kimi no Uso Music accompanies the ...
# 2    Made in Abyss The Abyss—a gaping chasm stretch...
# Name: text, dtype: object

# %%
import re

def clean_text(text):
    text = str(text).lower()
    text = re.sub(r'[^a-z0-9\s]', '', text)  # remove punctuation
    text = re.sub(r'\s+', ' ', text)         # remove extra spaces
    text = text.lower()
    return text

animeData['text'] = animeData['text'].apply(clean_text)
print(animeData['text'][:3])
# Out:
# 0    haikyuu second season following their particip...
# 1    shigatsu wa kimi no uso music accompanies the ...
# 2    made in abyss the abyssa gaping chasm stretchi...
# Name: text, dtype: object

# %%
from sklearn.preprocessing import MultiLabelBinarizer

# Convert string to list
formattedGenres = []
for genre in animeData['genre']:
    currentGenre = genre.split(',')
    currentGenreCleaned = re.sub(r'[\[\]\(\)\"\,]', '', genre)  # Remove non-alphanumeric characters
    finalGenreSplit = currentGenreCleaned.split("' '")  # Split into individual genres
    tempList = []
    for individualGenre in finalGenreSplit: 
        if individualGenre != '':
            individualGenre = re.sub(r'[\']', '', individualGenre)
            tempList.append(individualGenre.strip())
    formattedGenres.append(tempList)

print(formattedGenres[:3])
print(animeData['genre'][:3])
print(animeData['title'][:3])

# for i, genres in enumerate(formattedGenres):
#     animeData['genre_list'][i] = genres
        
print(formattedGenres[0][0])

mlb = MultiLabelBinarizer()
y = mlb.fit_transform(formattedGenres)

print(mlb.classes_)  # All genre labels
# Out:
# [['Comedy', 'Sports', 'Drama', 'School', 'Shounen'], ['Drama', 'Music', 'Romance', 'School', 'Shounen'], ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'Fantasy']]
# 0    ['Comedy', 'Sports', 'Drama', 'School', 'Shoun...
# 1    ['Drama', 'Music', 'Romance', 'School', 'Shoun...
# 2    ['Sci-Fi', 'Adventure', 'Mystery', 'Drama', 'F...
# Name: genre, dtype: object
# 0    Haikyuu!! Second Season
# 1    Shigatsu wa Kimi no Uso
# 2              Made in Abyss
# Name: title, dtype: object
# Comedy
# ['Action' 'Adventure' 'Cars' 'Comedy' 'Dementia' 'Demons' 'Drama' 'Ecchi'
#  'Fantasy' 'Game' 'Harem' 'Hentai' 'Historical' 'Horror' 'Josei' 'Kids'
#  'Magic' 'Martial Arts' 'Mecha' 'Military' 'Music' 'Mystery' 'Parody'
#  'Police' 'Psychological' 'Romance' 'Samurai' 'School' 'Sci-Fi' 'Seinen'
#  'Shoujo' 'Shoujo Ai' 'Shounen' 'Shounen Ai' 'Slice of Life' 'Space'
#  'Sports' 'Super Power' 'Supernatural' 'Thriller' 'Vampire' 'Yaoi' 'Yuri']

# %%
from sklearn.feature_extraction.text import TfidfVectorizer

# Fill missing values in 'text' column with empty strings for processing (Might remove them from the list of anime to train on later)
animeData['text'] = animeData['text'].fillna('')

# Create TF-IDF features from the 'text' column as vectorized input for the model (Limited to top 5000 words, removing English stop words)
tfidf = TfidfVectorizer(
    max_features=5000, 
    stop_words='english',
    ngram_range=(1,2)  # unigrams + bigrams
) # 

X = tfidf.fit_transform(animeData['text'])

# %%
from sklearn.model_selection import train_test_split

# First split: train + temp
X_train, X_temp, y_train, y_temp, idx_train, idx_temp = train_test_split(
    X, y, animeData.index, test_size=0.3, random_state=42
)

# Second split: validation + test
X_val, X_test, y_val, y_test, idx_val, idx_test = train_test_split(
    X_temp, y_temp, idx_temp, test_size=0.5, random_state=42
)

print(X_train.shape, X_val.shape, X_test.shape)
# Out:
# (13517, 5000) (2897, 5000) (2897, 5000)

# %%
from sklearn.linear_model import LogisticRegression
from sklearn.multiclass import OneVsRestClassifier

model = OneVsRestClassifier(LogisticRegression(max_iter=2000))
model.fit(X_train, y_train)
# Out:
# OneVsRestClassifier(estimator=LogisticRegression(max_iter=2000))

# %%
from sklearn.metrics import classification_report, f1_score

y_val_probs = model.predict_proba(X_val)
thresholds = [0.2, 0.3, 0.4, 0.5]
best_f1 = 0
best_threshold = 0.5

for t in thresholds:
    y_val_pred = (y_val_probs >= t).astype(int)
    f1 = f1_score(y_val, y_val_pred, average='micro')
    if f1 > best_f1:
        best_f1 = f1
        best_threshold = t

print("Best threshold:", best_threshold, "F1-micro on validation:", best_f1)

# --- 4️⃣ Predict on test set using best threshold ---
y_test_probs = model.predict_proba(X_test)
y_test_pred = (y_test_probs >= best_threshold).astype(int)

# Print classification report
print(classification_report(y_test, y_test_pred, target_names=mlb.classes_))


# Convert to readable genre names
true_labels = mlb.inverse_transform(y_test)
pred_labels = mlb.inverse_transform(y_test_pred)

# Compare first 100 samples
for i in range(100):
    print("TEXT:", animeData.loc[idx_test[i], 'title'])
    print("ACTUAL:", true_labels[i])
    print("PREDICTED:", pred_labels[i])
    print("-----")
# Out:
# Best threshold: 0.2 F1-micro on validation: 0.5744342775738316
#                precision    recall  f1-score   support
#
#        Action       0.52      0.81      0.64       638
#     Adventure       0.50      0.74      0.59       481
#          Cars       1.00      0.29      0.44        28
#        Comedy       0.45      0.94      0.61       959
#      Dementia       0.56      0.28      0.38        85
#        Demons       0.55      0.14      0.23        76
#         Drama       0.41      0.60      0.49       470
#         Ecchi       0.58      0.14      0.23        98
#       Fantasy       0.46      0.74      0.57       544
#          Game       0.88      0.26      0.40        58
#         Harem       0.50      0.01      0.03        69
#        Hentai       0.58      0.89      0.71       372
#    Historical       0.66      0.36      0.47       182
#        Horror       0.71      0.12      0.21        82
#         Josei       0.00      0.00      0.00        13
#          Kids       0.49      0.72      0.58       381
#         Magic       0.66      0.45      0.53       169
#  Martial Arts       0.54      0.14      0.23        49
#         Mecha       0.70      0.55      0.61       179
#      Military       0.68      0.38      0.49       104
#         Music       0.88      0.69      0.78       316
#       Mystery       0.85      0.36      0.51       147
#        Parody       0.66      0.23      0.34        91
#        Police       0.94      0.34      0.50        50
# Psychological       1.00      0.06      0.11        67
#       Romance       0.45      0.52      0.48       319
#       Samurai       0.85      0.28      0.42        39
#        School       0.51      0.62      0.56       263
#        Sci-Fi       0.55      0.72      0.63       392
#        Seinen       0.85      0.21      0.33       163
#        Shoujo       0.89      0.27      0.42       122
#     Shoujo Ai       0.00      0.00      0.00        23
#       Shounen       0.51      0.65      0.57       336
#    Shounen Ai       0.00      0.00      0.00        19
# Slice of Life       0.46      0.50      0.48       310
#         Space       0.78      0.51      0.62        82
#        Sports       0.85      0.49      0.62       106
#   Super Power       0.81      0.27      0.41       106
#  Supernatural       0.57      0.49      0.53       262
#      Thriller       0.00      0.00      0.00        30
#       Vampire       0.71      0.18      0.29        28
#          Yaoi       0.00      0.00      0.00         9
#          Yuri       0.00      0.00      0.00        10
#
#     micro avg       0.52      0.61      0.56      8327
#     macro avg       0.57      0.37      0.40      8327
#  weighted avg       0.56      0.61      0.54      8327
#   samples avg       0.54      0.64      0.55      8327
#
# TEXT: Matsumotokiyoshi x Osomatsu-san
# ACTUAL: ('Comedy',)
# PREDICTED: ('Comedy', 'Parody')
# -----
# TEXT: Bonobono (TV 2016)
# ACTUAL: ('Comedy', 'Slice of Life')
# PREDICTED: ('Comedy', 'Kids', 'Slice of Life')
# -----
# TEXT: Dragon Half
# ACTUAL: ('Comedy', 'Fantasy', 'Parody')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Fantasy', 'Shounen')
# -----
# TEXT: Himitsukessha Taka no Tsume: Christmas Daisakusen
# ACTUAL: ('Comedy', 'Parody', 'Super Power')
# PREDICTED: ('Comedy', 'Parody', 'Super Power')
# -----
# TEXT: Princess Rouge
# ACTUAL: ('Fantasy', 'Romance')
# PREDICTED: ('Action', 'Comedy', 'Drama', 'Fantasy', 'Romance')
# -----
# TEXT: Hinomaru Hatanosuke: Bakemonoyashiki no Maki
# ACTUAL: ('Supernatural',)
# PREDICTED: ('Action', 'Comedy')
# -----
# TEXT: Kero Kero Keroppi no Tomodachi wa Mahoutsukai
# ACTUAL: ('Kids', 'Magic')
# PREDICTED: ('Comedy', 'Fantasy', 'Kids')
# -----
# TEXT: Makeruna! Makendou
# ACTUAL: ('Comedy', 'Magic', 'Shounen')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Demons', 'Fantasy', 'Sci-Fi', 'Supernatural')
# -----
# TEXT: Trinity Seven: Nanatsu no Taizai to Nana Madoushi
# ACTUAL: ('Action', 'Comedy', 'Ecchi', 'Fantasy', 'Harem', 'Magic', 'Romance', 'School', 'Shounen', 'Supernatural')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Fantasy', 'Magic')
# -----
# TEXT: Fuurinkanzan
# ACTUAL: ('Hentai',)
# PREDICTED: ('Hentai',)
# -----
# TEXT: Luo Xiao Hei Zhan Ji (Movie)
# ACTUAL: ('Drama', 'Supernatural')
# PREDICTED: ('Adventure', 'Comedy', 'Fantasy', 'Historical', 'Supernatural')
# -----
# TEXT: Queen's Blade: Rurou no Senshi Specials
# ACTUAL: ('Action', 'Adventure', 'Ecchi', 'Fantasy')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Ecchi', 'Fantasy')
# -----
# TEXT: PES: Peace Eco Smile - Drive your Heart
# ACTUAL: ('Cars', 'Romance', 'Sci-Fi')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Drama', 'Mecha')
# -----
# TEXT: Tamako Love Story
# ACTUAL: ('Comedy', 'Romance', 'Slice of Life')
# PREDICTED: ('Comedy', 'Drama', 'Romance', 'School', 'Slice of Life')
# -----
# TEXT: Hoshizora Kiseki
# ACTUAL: ('Romance', 'Sci-Fi')
# PREDICTED: ('Action', 'Adventure', 'Drama', 'Fantasy', 'Sci-Fi')
# -----
# TEXT: Antinotice
# ACTUAL: ('Music',)
# PREDICTED: ('Music',)
# -----
# TEXT: Bobby ni Kubittake
# ACTUAL: ('Drama', 'Romance', 'Slice of Life')
# PREDICTED: ('Comedy', 'Drama', 'Hentai', 'Romance', 'Slice of Life')
# -----
# TEXT: Yans! Gans! Meat or Die
# ACTUAL: ('Adventure', 'Comedy')
# PREDICTED: ('Comedy',)
# -----
# TEXT: Yuru Yuri♪♪
# ACTUAL: ('Comedy', 'School', 'Shoujo Ai', 'Slice of Life')
# PREDICTED: ('Comedy', 'Romance', 'School', 'Slice of Life')
# -----
# TEXT: Casshern: Robot Hunter
# ACTUAL: ('Adventure', 'Mecha', 'Sci-Fi')
# PREDICTED: ('Action', 'Adventure', 'Mecha', 'Sci-Fi', 'Shounen')
# -----
# TEXT: Yu☆Gi☆Oh! The Dark Side of Dimensions Special: Eien no Rival - Yuugi to Kaiba!
# ACTUAL: ('Adventure', 'Game', 'Shounen')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Fantasy', 'Game', 'Shounen')
# -----
# TEXT: Uchuu Senkan Yamato 2205: Aratanaru Tabidachi
# ACTUAL: ('Action', 'Drama', 'Military', 'Sci-Fi', 'Space')
# PREDICTED: ('Comedy', 'Fantasy', 'Hentai', 'Kids')
# -----
# TEXT: Cosmo Warrior Zero
# ACTUAL: ('Action', 'Adventure', 'Military', 'Sci-Fi', 'Space')
# PREDICTED: ('Action', 'Adventure', 'Drama', 'Mecha', 'Military', 'Sci-Fi', 'Shounen', 'Space')
# -----
# TEXT: Majokko Club Yoningumi: A Kuukan kara no Alien X
# ACTUAL: ('Action', 'Comedy', 'Magic', 'Parody', 'Sci-Fi')
# PREDICTED: ('Comedy', 'Fantasy', 'Hentai', 'Magic', 'Sci-Fi')
# -----
# TEXT: To LOVE-Ru Darkness 2nd Specials
# ACTUAL: ('Comedy', 'Ecchi', 'Harem', 'Romance', 'School', 'Sci-Fi', 'Shounen')
# PREDICTED: ('Comedy', 'Ecchi', 'Fantasy', 'Romance', 'School', 'Sci-Fi', 'Shounen')
# -----
# TEXT: Psycho-Pass 3
# ACTUAL: ('Action', 'Police', 'Psychological', 'Sci-Fi')
# PREDICTED: ('Action', 'Comedy', 'Mystery', 'Sci-Fi')
# -----
# TEXT: Shion Special
# ACTUAL: ('Hentai',)
# PREDICTED: ('Action', 'Comedy', 'Fantasy')
# -----
# TEXT: Koi☆Sento
# ACTUAL: ('Comedy', 'Romance')
# PREDICTED: ('Adventure', 'Comedy', 'Drama', 'Sci-Fi')
# -----
# TEXT: Precure All Stars Movie: Haru no Carnival♪
# ACTUAL: ('Action', 'Comedy', 'Fantasy', 'Magic', 'Music', 'Shoujo')
# PREDICTED: ('Action', 'Comedy', 'Fantasy', 'Kids', 'Magic', 'Shoujo')
# -----
# TEXT: Date A Live II: Kurumi Star Festival
# ACTUAL: ('Romance', 'Slice of Life')
# PREDICTED: ('Comedy', 'Drama', 'Fantasy', 'Romance', 'Sci-Fi', 'Slice of Life')
# -----
# TEXT: B'T X Neo
# ACTUAL: ('Action', 'Adventure', 'Shounen')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Drama', 'Fantasy', 'Mecha', 'Sci-Fi', 'Shounen')
# -----
# TEXT: Muumindani no Suisei
# ACTUAL: ('Adventure', 'Comedy', 'Fantasy', 'Kids')
# PREDICTED: ('Adventure', 'Comedy', 'Fantasy', 'Kids')
# -----
# TEXT: Geobreeders: File-X Chibi Neko Dakkan
# ACTUAL: ('Adventure', 'Comedy', 'Shounen', 'Supernatural')
# PREDICTED: ('Action', 'Adventure', 'Comedy')
# -----
# TEXT: Baki
# ACTUAL: ('Action', 'Martial Arts', 'Shounen')
# PREDICTED: ('Action', 'Adventure', 'Fantasy', 'Shounen')
# -----
# TEXT: World Fool News (TV) Part II
# ACTUAL: ('Comedy', 'Slice of Life')
# PREDICTED: ('Action', 'Comedy', 'Fantasy')
# -----
# TEXT: Asari-chan: Ai no Marchen Shoujo
# ACTUAL: ('Adventure', 'Shoujo', 'Slice of Life')
# PREDICTED: ('Comedy',)
# -----
# TEXT: Tokubetsu Byoutou
# ACTUAL: ('Hentai',)
# PREDICTED: ('Hentai',)
# -----
# TEXT: Toaru Kagaku no Railgun
# ACTUAL: ('Action', 'Sci-Fi', 'Super Power')
# PREDICTED: ('Action', 'Comedy', 'Sci-Fi', 'Super Power')
# -----
# TEXT: Usagi no Mofy
# ACTUAL: ('Kids',)
# PREDICTED: ('Comedy', 'Fantasy', 'Kids')
# -----
# TEXT: Rita to Nantoka
# ACTUAL: ('Slice of Life',)
# PREDICTED: ('Comedy', 'Fantasy', 'Kids', 'Slice of Life')
# -----
# TEXT: Ghost Messenger Movie
# ACTUAL: ('Action', 'Supernatural')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Fantasy', 'Supernatural')
# -----
# TEXT: Shingeki no Kyojin The Final Season
# ACTUAL: ('Action', 'Drama', 'Fantasy', 'Military', 'Mystery', 'Shounen', 'Super Power')
# PREDICTED: ('Action', 'Drama', 'Fantasy', 'Shounen', 'Super Power')
# -----
# TEXT: Yuuki Yuuna wa Yuusha de Aru: Washio Sumi no Shou 3 - Yakusoku
# ACTUAL: ('Drama', 'Fantasy', 'Magic', 'Slice of Life')
# PREDICTED: ('Comedy', 'Fantasy', 'Hentai', 'Kids')
# -----
# TEXT: Mizuiro
# ACTUAL: ('Hentai',)
# PREDICTED: ('Comedy', 'Drama', 'Hentai', 'Romance')
# -----
# TEXT: Pokemon Movie 17: Hakai no Mayu to Diancie
# ACTUAL: ('Adventure', 'Fantasy', 'Kids')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Drama', 'Fantasy', 'Kids')
# -----
# TEXT: Ojiichan wa Boku no Hero
# ACTUAL: ('Drama', 'Kids')
# PREDICTED: ('Drama', 'Kids')
# -----
# TEXT: Drifters: Special Edition
# ACTUAL: ('Action', 'Adventure', 'Comedy', 'Fantasy', 'Historical', 'Samurai', 'Seinen')
# PREDICTED: ('Action', 'Comedy', 'School', 'Seinen', 'Slice of Life')
# -----
# TEXT: Ikenai Koto The Animation
# ACTUAL: ('Hentai',)
# PREDICTED: ('Hentai',)
# -----
# TEXT: Aoi Umi to Shounen
# ACTUAL: ('Slice of Life',)
# PREDICTED: ('Action', 'Adventure', 'Drama')
# -----
# TEXT: Jin-Rou
# ACTUAL: ('Drama', 'Military', 'Police', 'Psychological', 'Romance')
# PREDICTED: ('Action', 'Drama', 'Romance', 'Sci-Fi')
# -----
# TEXT: Dokachin
# ACTUAL: ('Comedy', 'Kids')
# PREDICTED: ('Comedy',)
# -----
# TEXT: Humane
# ACTUAL: ('Dementia', 'Music')
# PREDICTED: ('Music',)
# -----
# TEXT: Hachigatsu no Cinderella Nine
# ACTUAL: ('Music', 'Sports')
# PREDICTED: ()
# -----
# TEXT: Kimagure Orange☆Road
# ACTUAL: ('Comedy', 'Drama', 'Romance', 'School', 'Shounen', 'Slice of Life', 'Super Power')
# PREDICTED: ('Comedy', 'Romance', 'Shounen')
# -----
# TEXT: True Blue
# ACTUAL: ('Hentai',)
# PREDICTED: ('Comedy', 'Drama', 'Hentai', 'Romance', 'School')
# -----
# TEXT: Jungle de Ikou!
# ACTUAL: ('Action', 'Adventure', 'Comedy', 'Ecchi', 'Magic')
# PREDICTED: ('Adventure', 'Comedy', 'Fantasy', 'Magic')
# -----
# TEXT: Aru Mori no wo Hanashi: Rururu no Rule
# ACTUAL: ('Kids',)
# PREDICTED: ('Adventure', 'Fantasy', 'Kids')
# -----
# TEXT: Watashi ga Motenai no wa Dou Kangaetemo Omaera ga Warui!: Motenaishi, Nazomeite Miru
# ACTUAL: ('Comedy', 'School', 'Slice of Life')
# PREDICTED: ('Comedy', 'Romance', 'School', 'Slice of Life')
# -----
# TEXT: Go! Go! 575
# ACTUAL: ('Slice of Life',)
# PREDICTED: ('Comedy', 'Sci-Fi')
# -----
# TEXT: Robotics;Notes
# ACTUAL: ('Drama', 'Mecha', 'Mystery', 'School', 'Sci-Fi')
# PREDICTED: ('Comedy', 'Romance', 'School', 'Shounen', 'Slice of Life')
# -----
# TEXT: Robo to Shoujo (Kari): Oshirase Gekijou (Kari)
# ACTUAL: ('Comedy', 'Sci-Fi')
# PREDICTED: ('Comedy',)
# -----
# TEXT: Final Fantasy XV: Episode Ardyn - Prologue
# ACTUAL: ('Action',)
# PREDICTED: ('Drama', 'Fantasy', 'Supernatural')
# -----
# TEXT: Idol Ace
# ACTUAL: ('Comedy',)
# PREDICTED: ('Comedy', 'Music')
# -----
# TEXT: Kuuchuu Buranko
# ACTUAL: ('Comedy', 'Drama', 'Psychological', 'Seinen')
# PREDICTED: ('Comedy', 'Drama', 'Hentai')
# -----
# TEXT: The☆Doraemons: Mushimushi Pyonpyon Daisakusen!
# ACTUAL: ('Fantasy',)
# PREDICTED: ('Comedy', 'Fantasy', 'Hentai', 'Kids')
# -----
# TEXT: Kairaku Satsujin Chousakan Kouji
# ACTUAL: ('Hentai',)
# PREDICTED: ('Action', 'Comedy', 'Fantasy', 'Hentai', 'Horror', 'Supernatural')
# -----
# TEXT: Hakuouki Reimeiroku
# ACTUAL: ('Action', 'Drama', 'Historical', 'Josei', 'Samurai', 'Supernatural')
# PREDICTED: ('Action', 'Drama', 'Historical', 'Samurai', 'Sci-Fi')
# -----
# TEXT: Soukou no Strain
# ACTUAL: ('Drama', 'Ecchi', 'Mecha', 'Military', 'Sci-Fi', 'Space')
# PREDICTED: ('Action', 'Adventure', 'Drama', 'Mecha', 'Military', 'Sci-Fi')
# -----
# TEXT: Hong Mao Lan Tu: Yongzhe Guilai
# ACTUAL: ('Kids',)
# PREDICTED: ('Comedy', 'Fantasy', 'Hentai', 'Kids')
# -----
# TEXT: Shinsekai yori
# ACTUAL: ('Drama', 'Horror', 'Mystery', 'Psychological', 'Sci-Fi', 'Supernatural')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Drama', 'Fantasy', 'Sci-Fi')
# -----
# TEXT: Touka Gettan
# ACTUAL: ('Drama', 'Romance', 'Supernatural')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Drama', 'Fantasy', 'Magic', 'Romance', 'Supernatural')
# -----
# TEXT: Omoi no Kakera
# ACTUAL: ('Slice of Life',)
# PREDICTED: ('Drama', 'Slice of Life')
# -----
# TEXT: Tate no Yuusha no Nariagari 2nd Season
# ACTUAL: ('Action', 'Adventure', 'Drama', 'Fantasy')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Fantasy')
# -----
# TEXT: Super Lovers 2
# ACTUAL: ('Comedy', 'Drama', 'Romance', 'Shounen Ai', 'Slice of Life')
# PREDICTED: ('Comedy', 'Romance')
# -----
# TEXT: Tokyo SOS
# ACTUAL: ()
# PREDICTED: ('Dementia', 'Music')
# -----
# TEXT: Hage
# ACTUAL: ('Drama', 'Kids', 'School')
# PREDICTED: ('Drama', 'Kids')
# -----
# TEXT: Cute Kenkyuukai
# ACTUAL: ('Music',)
# PREDICTED: ('Music',)
# -----
# TEXT: Utakata Hanabi
# ACTUAL: ('Music',)
# PREDICTED: ('Music',)
# -----
# TEXT: Ken to Kaijuu
# ACTUAL: ('Fantasy', 'Kids', 'Magic')
# PREDICTED: ('Comedy', 'Fantasy', 'Kids')
# -----
# TEXT: Kaze ga Tsuyoku Fuiteiru
# ACTUAL: ('Comedy', 'Drama', 'Sports')
# PREDICTED: ('Comedy', 'Drama', 'Romance', 'School', 'Slice of Life')
# -----
# TEXT: Pinky Monkey no Umareta Hi
# ACTUAL: ('Adventure',)
# PREDICTED: ('Kids',)
# -----
# TEXT: Love Colon
# ACTUAL: ('Hentai',)
# PREDICTED: ('Hentai', 'Romance')
# -----
# TEXT: Saa Ikou! Tamagotchi
# ACTUAL: ('Kids',)
# PREDICTED: ('Comedy', 'Kids')
# -----
# TEXT: Yuujou no Kickoff
# ACTUAL: ('Drama', 'Kids', 'Sports')
# PREDICTED: ('Comedy', 'School', 'Shounen', 'Sports')
# -----
# TEXT: Princess Nine: Kisaragi Joshikou Yakyuubu
# ACTUAL: ('Drama', 'Romance', 'Sports')
# PREDICTED: ('Comedy', 'School', 'Shounen', 'Sports')
# -----
# TEXT: dMatsu-san
# ACTUAL: ('Comedy', 'Parody')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Fantasy')
# -----
# TEXT: Momoiro Bouenkyou Anime Edition
# ACTUAL: ('Hentai',)
# PREDICTED: ('Hentai',)
# -----
# TEXT: Haikyuu!!: To the Top 2nd Season
# ACTUAL: ('Comedy', 'Drama', 'School', 'Shounen', 'Sports')
# PREDICTED: ('Comedy', 'Fantasy', 'Hentai', 'Kids')
# -----
# TEXT: Poputepipikku Specials
# ACTUAL: ('Comedy', 'Parody')
# PREDICTED: ('Comedy', 'Shounen')
# -----
# TEXT: Jie Mo Ren
# ACTUAL: ('Action', 'Fantasy', 'Mystery', 'Supernatural')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Fantasy', 'Sci-Fi', 'Shounen', 'Supernatural')
# -----
# TEXT: Zettai Karen Children
# ACTUAL: ('Action', 'Comedy', 'Shounen', 'Supernatural')
# PREDICTED: ('Action', 'Comedy')
# -----
# TEXT: Kumori Nochi Hare
# ACTUAL: ('Drama', 'Kids')
# PREDICTED: ('Drama', 'Kids')
# -----
# TEXT: Doushitemo Eto ni Hairitai
# ACTUAL: ('Comedy',)
# PREDICTED: ('Comedy', 'Romance', 'Slice of Life')
# -----
# TEXT: Shiki Specials
# ACTUAL: ('Horror', 'Mystery', 'Supernatural', 'Thriller', 'Vampire')
# PREDICTED: ('Action', 'Comedy', 'School')
# -----
# TEXT: Dragon Ball Super Movie: Broly
# ACTUAL: ('Action', 'Adventure', 'Comedy', 'Fantasy', 'Martial Arts', 'Shounen', 'Super Power')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Fantasy', 'Sci-Fi', 'Shounen', 'Super Power')
# -----
# TEXT: Lovely★Complex
# ACTUAL: ('Comedy', 'Romance', 'Shoujo')
# PREDICTED: ('Comedy', 'Romance', 'School', 'Slice of Life')
# -----
# TEXT: Shiritsu Araiso Koutougakkou Seitokai Shikkoubu
# ACTUAL: ('Comedy', 'Shounen Ai', 'Sports')
# PREDICTED: ('Comedy', 'Romance', 'School', 'Shounen', 'Slice of Life')
# -----
# TEXT: Taneyamagahara no Yoru
# ACTUAL: ('Fantasy', 'Kids', 'Psychological', 'Slice of Life')
# PREDICTED: ('Comedy', 'Fantasy')
# -----
# TEXT: Kaden Manzai John TV Show!
# ACTUAL: ('Comedy',)
# PREDICTED: ('Comedy', 'Fantasy', 'Hentai', 'Kids')
# -----
# TEXT: Ta ga Tame no Alchemist
# ACTUAL: ('Action', 'Adventure', 'Fantasy', 'Magic')
# PREDICTED: ('Action', 'Adventure', 'Comedy', 'Drama', 'Fantasy')
# -----
# /home/zayne/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/zayne/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Precision is ill-defined and being set to 0.0 in samples with no predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/zayne/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: Recall is ill-defined and being set to 0.0 in samples with no true labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])
# /home/zayne/.local/lib/python3.10/site-packages/sklearn/metrics/_classification.py:1731: UndefinedMetricWarning: F-score is ill-defined and being set to 0.0 in samples with no true nor predicted labels. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, f"{metric.capitalize()} is", result.shape[0])

# %%
for i, genre in enumerate(mlb.classes_):
    top10 = np.argsort(model.estimators_[i].coef_[0])[-10:]
    print(f"\nTop words for {genre}:")
    print([tfidf.get_feature_names_out()[j] for j in top10])
# Out:
# Top words for Action:
# ['strike', 'hunter', 'iii', 'arc', 'lupin', 'precure', 'fighting', 'gintama', 'fight', 'battle']
#
# Top words for Adventure:
# ['saiyuuki', 'travel', 'land', 'conan', 'lupin', 'world', 'bouken', 'adventures', 'journey', 'adventure']
#
# Top words for Cars:
# ['takumi', 'trilogy', 'driver', 'cars', 'race', 'bus', 'stage', 'racing', 'initial', 'car']
#
# Top words for Comedy:
# ['gintama', 'doraemon', 'source ann', 'pokemon', 'funny', 'parody', 'lupin', 'shorts', 'gag', 'comedy']
#
# Top words for Dementia:
# ['taku', 'work', 'experimental', 'takashi', 'keiichi', 'collaborative', 'short', 'animation', 'tanaami', 'film']
#
# Top words for Demons:
# ['berserk', 'choujin', 'devil', 'natsume', 'inuyasha', 'maou', 'oni', 'youkai', 'demons', 'demon']
#
# Top words for Drama:
# ['lives', 'earthquake', 'yuuki', 'mother', 'drawn', 'kyojin', 'hi', 'natsume', 'educational film', 'educational']
#
# Top words for Ecchi:
# ['queens blade', 'witches', 'perverted', 'magical', 'ova', 'girls', 'academy', 'specials', 'souma', 'beautiful']
#
# Top words for Fantasy:
# ['monsters', 'journey', 'piece', 'world', 'precure', 'magic', 'land', 'dragon', 'fantasy', 'pokemon']
#
# Top words for Game:
# ['duel', 'games', 'online', 'world', 'yugioh', 'mahjong', 'bakugan', 'vanguard', 'card', 'game']
#
# Top words for Harem:
# ['saikyou', 'women', 'episode', 'school', 'hayate', 'ova', 'academy', 'harem', 'tenchi', 'girls']
#
# Top words for Hentai:
# ['hentai', 'woman', 'lust', 'based game', 'based', 'adult', 'women', 'erotic', 'sexual', 'sex']
#
# Top words for Historical:
# ['sengoku', 'nobunaga', 'period', 'samurai', 'hetalia', 'historical', 'gintama', 'monogatari', 'war', 'edo']
#
# Top words for Horror:
# ['demons', 'ghost', 'dead', 'gegege', 'monster', 'kitarou', 'hellsing', 'monsters', 'zombie', 'horror']
#
# Top words for Josei:
# ['love', 'episode', 'chihaya', 'rakugo', 'shinichi', 'chizuru', 'chiaki', 'shinsengumi', 'nodame', 'hakuouki']
#
# Top words for Kids:
# ['educational film', 'children', 'uta', 'kitty', 'kids', 'doraemon', 'safety', 'childrens', 'pokemon', 'educational']
#
# Top words for Magic:
# ['witch', 'lina', 'mahoutsukai', 'fairy', 'sailor', 'witches', 'precure', 'mahou', 'magic', 'magical']
#
# Top words for Martial Arts:
# ['spirit', 'dragon', 'arts', 'ninjas', 'martial arts', 'ken', 'ranma', 'ninja', 'naruto', 'martial']
#
# Top words for Mecha:
# ['giant', 'suit', 'robots', 'transformers', 'pilot', 'macross', 'earth', 'mecha', 'gundam', 'robot']
#
# Top words for Military:
# ['break', 'macross', 'force', 'yamato', 'panzer', 'empire', 'gundam', 'girls panzer', 'military', 'war']
#
# Top words for Music:
# ['macross', 'idols', 'musical', 'uta', 'music video', 'band', 'idol', 'video', 'song', 'music']
#
# Top words for Mystery:
# ['mysterious', 'mysteries', 'city hunter', 'solve', 'araragi', 'holmes', 'lupin', 'conan', 'mystery', 'detective']
#
# Top words for Parody:
# ['sd', 'punch', 'collaboration', 'gag', 'gintoki', 'osomatsusan', 'shorts', 'hetalia', 'gintama', 'parody']
#
# Top words for Police:
# ['crimes', 'special', 'crime', 'cop', 'dirty', 'criminals', 'detective conan', 'detective', 'conan', 'police']
#
# Top words for Psychological:
# ['truth', 'warau', 'shell', 'mal', 'written', 'mal rewrite', 'written mal', 'game', 'rewrite', 'death']
#
# Top words for Romance:
# ['xiao', 'romantic', 'novel', 'sailor', 'hatsukoi', 'girl', 'feelings', 'romance', 'relationship', 'love']
#
# Top words for Samurai:
# ['nobunaga', 'meiji', 'yorozuya', 'hakuouki', 'shinsengumi', 'gintoki', 'kenshin', 'sengoku', 'gintama', 'samurai']
#
# Top words for School:
# ['lelouch', 'classmates', 'high', 'girls panzer', 'classmate', 'club', 'class', 'students', 'academy', 'school']
#
# Top words for Sci-Fi:
# ['gintama', 'dr', 'robots', 'earth', 'future', 'robot', 'galaxy', 'alien', 'space', 'planet']
#
# Top words for Seinen:
# ['crayon shinchan', 'lupin iii', 'shinnosuke', 'shinchan', 'nohara', 'manga', 'non', 'hellsing', 'initial', 'lupin']
#
# Top words for Shoujo:
# ['cure', 'momo', 'girl', 'mahou', 'idol', 'princess', 'mami', 'natsume', 'sailor', 'precure']
#
# Top words for Shoujo Ai:
# ['yamada', 'high school', 'akari', 'ga', 'high', 'girl', 'yukino', 'school', 'yuru', 'yuri']
#
# Top words for Shounen:
# ['gintama', 'haikyuu', 'tennis', 'kinnikuman', 'naruto', 'tenchi', 'luffy', 'teekyuu', 'piece', 'conan']
#
# Top words for Shounen Ai:
# ['men', 'wei', 'honoo', 'school', 'satou', 'lovers', 'ritsu', 'love', 'junjou', 'hatsukoi']
#
# Top words for Slice of Life:
# ['lives', 'company', 'rope', 'yuru', 'everyday', 'natsume', 'daily', 'peeping', 'peeping life', 'life']
#
# Top words for Space:
# ['tenchi', 'crew', 'planet', 'ginga', 'gundam', 'uchuu', 'macross', 'galaxy', 'earth', 'space']
#
# Top words for Sports:
# ['beyblade', 'racing', 'haikyuu', 'sport', 'kinnikuman', 'tennis', 'teekyuu', 'soccer', 'team', 'baseball']
#
# Top words for Super Power:
# ['abilities', 'hero', 'piece', 'lelouch', 'toaru', 'zhu', 'dragon ball', 'ultraman', 'powers', 'naruto']
#
# Top words for Supernatural:
# ['spirit', 'ghosts', 'busters', 'vampire', 'demons', 'spirits', 'ghost', 'youkai', 'demon', 'supernatural']
#
# Top words for Thriller:
# ['kaiji', 'mal', 'written', 'mal rewrite', 'written mal', 'rewrite', 'death', 'shiki', 'okabe', 'mikiya']
#
# Top words for Vampire:
# ['bizarre', 'ova', 'koyomi', 'owari', 'supernatural', 'hellsing', 'araragi', 'vampires', 'blood', 'vampire']
#
# Top words for Yaoi:
# ['nai', 'mizuki', 'takes', 'riki', 'boss', 'ayase', 'specials included', 'men', 'love', 'pico']
#
# Top words for Yuri:
# ['sex', 'mai', 'pleasure', 'lemon', 'cream', 'sequel', 'houkago', 'dr', 'sexual', 'club']
